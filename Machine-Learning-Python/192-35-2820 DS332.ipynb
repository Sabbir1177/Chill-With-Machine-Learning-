# %% [markdown]
# # Import the required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading our Dataset

# %%
df=pd.read_csv("Real estate.csv")
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# # Visualizing the Data using HeatMap

# %%
sns.heatmap(df.isnull(),cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Check the correlations in the dataset

# %%
df.corr()
# Out:
#                                               No  X1 transaction date  \
# No                                      1.000000            -0.048658
# X1 transaction date                    -0.048658             1.000000
# X2 house age                           -0.032808             0.017549
# X3 distance to the nearest MRT station -0.013573             0.060880
# X4 number of convenience stores        -0.012699             0.009635
# X5 latitude                            -0.010110             0.035058
# X6 longitude                           -0.011059            -0.041082
# Y house price of unit area             -0.028587             0.087491
#
#                                         X2 house age  \
# No                                         -0.032808
# X1 transaction date                         0.017549
# X2 house age                                1.000000
# X3 distance to the nearest MRT station      0.025622
# X4 number of convenience stores             0.049593
# ...

# %% [markdown]
# # Make features

# %%
x=df["X4 number of convenience stores"].values.reshape(-1,1)
y=df["Y house price of unit area"].values.reshape(-1,1)
y
# Out:
# array([[ 37.9],
#        [ 42.2],
#        [ 47.3],
#        [ 54.8],
#        [ 43.1],
#        [ 32.1],
#        [ 40.3],
#        [ 46.7],
#        [ 18.8],
#        [ 22.1],
#        [ 41.4],
#        [ 58.1],
#        [ 39.3],
#        [ 23.8],
#        [ 34.3],
#        [ 50.5],
#        [ 70.1],
#        [ 37.4],
#        [ 42.3],
#        [ 47.7],
#        [ 29.3],
#        [ 51.6],
#        [ 24.6],
#        [ 47.9],
#        [ 38.8],
#        [ 27. ],
#        [ 56.2],
#        [ 33.6],
#        [ 47. ],
#        [ 57.1],
#        [ 22.1],
#        [ 25. ],
#        [ 34.2],
#        [ 49.3],
#        [ 55.1],
#        [ 27.3],
#        [ 22.9],
#        [ 25.3],
#        [ 47.7],
#        [ 46.2],
#        [ 15.9],
#        [ 18.2],
#        [ 34.7],
#        [ 34.1],
#        [ 53.9],
#        [ 38.3],
#        [ 42. ],
#        [ 61.5],
#        [ 13.4],
#        [ 13.2],
#        [ 44.2],
#        [ 20.7],
#        [ 27. ],
#        [ 38.9],
#        [ 51.7],
# ...

# %%
x
# Out:
# array([[10],
#        [ 9],
#        [ 5],
#        [ 5],
#        [ 5],
#        [ 3],
#        [ 7],
#        [ 6],
#        [ 1],
#        [ 3],
#        [ 1],
#        [ 9],
#        [ 5],
#        [ 4],
#        [ 4],
#        [ 2],
#        [ 6],
#        [ 1],
#        [ 8],
#        [ 7],
#        [ 3],
#        [ 7],
#        [ 1],
#        [ 7],
#        [ 4],
#        [ 2],
#        [ 5],
#        [ 5],
#        [ 4],
#        [ 5],
#        [ 0],
#        [ 7],
#        [ 1],
#        [ 6],
#        [ 7],
#        [ 0],
#        [ 2],
#        [ 1],
#        [ 6],
#        [ 5],
#        [ 0],
#        [ 0],
#        [ 5],
#        [ 6],
#        [ 4],
#        [ 8],
#        [ 9],
#        [ 3],
#        [ 0],
#        [ 1],
#        [ 4],
#        [ 1],
#        [ 3],
#        [ 5],
#        [ 5],
#        [ 0],
#        [ 8],
#        [ 7],
#        [ 1],
#        [ 5],
#        [ 2],
#        [ 6],
#        [ 3],
#        [ 4],
#        [ 0],
#        [ 8],
# ...

# %% [markdown]
# # Train test splitting

# %%
from sklearn.model_selection import train_test_split
train_set_x,test_set_x,train_set_y,test_set_y=train_test_split(x,y,test_size=0.3,shuffle=True)
train_set_x.shape
# Out:
# (289, 1)

# %% [markdown]
# # Generating the model and train regression model

# %%
from sklearn.linear_model import LinearRegression
r=LinearRegression()
r.fit(train_set_x,train_set_y)
# Out:
# LinearRegression()

# %%
y_predict=r.predict(test_set_x)
y_predict
# Out:
# array([[28.15033769],
#        [33.14706992],
#        [28.15033769],
#        [28.15033769],
#        [38.14380214],
#        [28.15033769],
#        [28.15033769],
#        [30.6487038 ],
#        [30.6487038 ],
#        [50.63563272],
#        [45.63890049],
#        [43.14053437],
#        [28.15033769],
#        [40.64216826],
#        [40.64216826],
#        [40.64216826],
#        [43.14053437],
#        [40.64216826],
#        [30.6487038 ],
#        [43.14053437],
#        [45.63890049],
#        [35.64543603],
#        [40.64216826],
#        [40.64216826],
#        [45.63890049],
#        [35.64543603],
#        [48.1372666 ],
#        [38.14380214],
#        [48.1372666 ],
#        [35.64543603],
#        [40.64216826],
#        [53.13399883],
#        [40.64216826],
#        [48.1372666 ],
#        [40.64216826],
#        [28.15033769],
#        [43.14053437],
#        [40.64216826],
#        [35.64543603],
#        [35.64543603],
#        [35.64543603],
# ...

# %% [markdown]
# # Check Coefficients, Intercept, R-Squared Value

# %%
r.coef_
# Out:
# array([[2.49836611]])

# %%
r.intercept_
# Out:
# array([28.15033769])

# %%
y_pred=r.intercept_+r.coef_+test_set_x
y_pred
# Out:
# array([[30.6487038],
#        [32.6487038],
#        [30.6487038],
#        [30.6487038],
#        [34.6487038],
#        [30.6487038],
#        [30.6487038],
#        [31.6487038],
#        [31.6487038],
#        [39.6487038],
#        [37.6487038],
#        [36.6487038],
#        [30.6487038],
#        [35.6487038],
#        [35.6487038],
#        [35.6487038],
#        [36.6487038],
#        [35.6487038],
#        [31.6487038],
#        [36.6487038],
#        [37.6487038],
#        [33.6487038],
#        [35.6487038],
#        [35.6487038],
#        [37.6487038],
#        [33.6487038],
#        [38.6487038],
#        [34.6487038],
#        [38.6487038],
#        [33.6487038],
#        [35.6487038],
#        [40.6487038],
#        [35.6487038],
#        [38.6487038],
#        [35.6487038],
#        [30.6487038],
#        [36.6487038],
#        [35.6487038],
#        [33.6487038],
#        [33.6487038],
#        [33.6487038],
#        [38.6487038],
#        [36.6487038],
# ...

# %% [markdown]
# # Evaluate the model and give a proper view of performance

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print("actual_data:",test_set_y ,"predictive values:",y_pred)
mean_absolute_error(test_set_y,y_pred),np.sqrt(mean_squared_error(test_set_y,y_pred))
# Out:
# actual_data: [[24.7]
#  [34.1]
#  [13.7]
#  [16.7]
#  [34.3]
#  [22.3]
#  [15.6]
#  [37.4]
#  [41.4]
#  [52.7]
#  [53.5]
#  [40.6]
#  [15.9]
#  [40.8]
#  [32.9]
#  [51.4]
#  [53.7]
#  [59.6]
#  [25.3]
#  [70.1]
#  [51.6]
#  [27. ]
#  [41.1]
#  [55. ]
#  [55.1]
#  [34.6]
#  [43.2]
#  [44.2]
#  [38.1]
#  [36.5]
#  [51.8]
#  [37.9]
#  [42.1]
#  [26.5]
#  [47.3]
#  [25.3]
#  [40.8]
#  [39.4]
#  [40.8]
#  [27.7]
#  [27.7]
#  [40.2]
#  [63.2]
#  [28.8]
#  [24.8]
#  [25.3]
#  [23.5]
#  [37.2]
#  [39.3]
#  [25.7]
#  [53. ]
#  [48.1]
#  [42.7]
#  [23. ]
#  [44. ]
#  [23.6]
#  [34.4]
#  [49.8]
#  [24.4]
#  [12.9]
#  [31.1]
#  [40.9]
#  [37.5]
#  [14.7]
#  [33.4]
#  [52.5]
#  [21.4]
#  [48. ]
#  [11.2]
#  [41.9]
#  [35.7]
#  [63.9]
#  [24.7]
#  [58.1]
#  [52.2]
#  [26.9]
#  [39.5]
#  [53.9]
#  [14.4]
#  [43.1]
#  [55.9]
#  [60.7]
#  [45.7]
#  [20.7]
#  [20.9]
#  [28.5]
#  [50.5]
#  [18.8]
#  [32.5]
#  [31.3]
#  [62.1]
#  [38.1]
#  [43.5]
#  [44.9]
#  [42.6]
#  [40.6]
#  [38.2]
#  [42.2]
# ...

# %%
plt.scatter(test_set_x,test_set_y,color ="green")
plt.scatter(test_set_x,y_pred,color ="red")

# %%
plt.scatter(train_set_x,train_set_y, color ="green" , alpha= 0.7)
plt.plot(train_set_x, r.predict(train_set_x), color = "red")
plt.xlabel('X4 number of convenience stores')
plt.ylabel('Y house price of unit area')
plt.show()
